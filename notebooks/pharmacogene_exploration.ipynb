# %%
import pandas as pd
import matplotlib.pyplot as plt

genes = ['CYP2D6', 'CYP2C19', 'TPMT', 'DPYD', 'SLCO1B1']
drugs = [50, 30, 20, 15, 25]

df = pd.DataFrame({
    'Gene': genes,
    'Associated_Drugs': drugs
})

print(df)
# Out:
#       Gene  Associated_Drugs
# 0   CYP2D6                50
# 1  CYP2C19                30
# 2     TPMT                20
# 3     DPYD                15
# 4  SLCO1B1                25

# %%
print("Hello Busayo!")
# Out:
# Hello Busayo!

# %%
plt.figure(figsize=(7,5))

plt.bar(df['Gene'], df['Associated_Drugs'])

plt.xlabel('Pharmacogene')
plt.ylabel('Number of Associated Drugs')
plt.title('Drug Associations of Key Pharmacogenes')

plt.xticks(rotation=45)

plt.savefig('../figures/pharmacogene_plot.png')

plt.show()

# %% [markdown]
# # Pharmacogenomics Variant Analysis
#
# ## Objective
# To investigate clinically actionable pharmacogenes and their associated medications.
#
# Genes of interest:
# - CYP2D6
# - CYP2C19
# - TPMT
# - DPYD
# - SLCO1B1

# %%
import pandas as pd

data = {
    'Gene': ['CYP2D6','CYP2C19','TPMT','DPYD','SLCO1B1'],
    'Drug': ['Codeine',
             'Clopidogrel',
             'Azathioprine',
             'Fluorouracil',
             'Simvastatin'],
    'Clinical_Concern':[
        'Poor metabolism',
        'Reduced efficacy',
        'Myelosuppression risk',
        'Severe toxicity',
        'Myopathy risk'
    ]
}

df = pd.DataFrame(data)

df
# Out:
#       Gene          Drug       Clinical_Concern
# 0   CYP2D6       Codeine        Poor metabolism
# 1  CYP2C19   Clopidogrel       Reduced efficacy
# 2     TPMT  Azathioprine  Myelosuppression risk
# 3     DPYD  Fluorouracil        Severe toxicity
# 4  SLCO1B1   Simvastatin          Myopathy risk

# %%
df.to_csv('../data/pharmacogene_dataset.csv',
          index=False)

print("Dataset saved successfully.")
# Out:
# Dataset saved successfully.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,4))

plt.bar(df['Gene'],
        [1,1,1,1,1])

plt.title('Clinically Important Pharmacogenes')

plt.xlabel('Gene')

plt.ylabel('Presence in Dataset')

plt.show()
